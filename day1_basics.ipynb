# %%
print("Hello,World!")
print("我開始學習python轉行了")
print("今天是:",2026,"年",2,"月")
# Out:
# Hello,World!
# 我開始學習python轉行了
# 今天是: 2026 年 2 月

# %%
print("學習phthon的第一步")
name = "我的學習日誌"
print(name)
days = 1
print("這是第",days,"天")
# Out:
# 學習phthon的第一步
# 我的學習日誌
# 這是第 1 天

# %%
print("要努力啊")
name = ("Leo Cheung")
print(name)
days = 1
print(name,"第",days,"天學習")
# Out:
# 要努力啊
# Leo Cheung
# Leo Cheung 第 1 天學習

# %%
my_name = "Python學習者"
my_day = 1
print("我是",my_name)
print("學習天數",my_day)
my_day = my_day + 1
print("明天是",my_day,"天")
# Out:
# h我是 Python學習者
# 學習天數 1
# 明天是 2 天

# %%
my_name = "張溍健"
name = "想轉行"
my_day = 1

print("我是",my_name,name)
print("預計學習",my_day,"天")

my_day = (1+29)*4
print("如果每天學習4小時共",my_day,"小時")
# Out:
# 我是 張溍健 想轉行
# 預計學習 1 天
# 如果每天學習4小時共 120 小時
